# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pcts = pd.read_csv('./pcts.csv', sep=';', dtype={'pct_200':float, 'pct_500':float, 'pct_800':float, 'pct_1600':float})

# %%
pcts
# Out:
#                                               file name    pct_200    pct_500  \
# 0     /Users/nicolas/Documents/ime/compmus/mestrado/...  14.830827  23.235294
# 1     /Users/nicolas/Documents/ime/compmus/mestrado/...  14.135338  16.470588
# 2     /Users/nicolas/Documents/ime/compmus/mestrado/...   4.774436   9.411765
# 3     /Users/nicolas/Documents/ime/compmus/mestrado/...  10.902256  17.254902
# 4     /Users/nicolas/Documents/ime/compmus/mestrado/...  28.928571  34.313725
# ...                                                 ...        ...        ...
# 1031  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   7.406015  13.627451
# 1032  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...  12.988722  20.588235
# 1033  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   8.007519  13.039216
# 1034  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   7.687970  16.666667
# 1035  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...  15.432331  28.725490
#
#         pct_800   pct_1600                         pct_multilevel_2  \
# 0     29.054054  42.592593               [42.592592592592595, 82.5]
# 1     25.675676  42.592593  [42.592592592592595, 64.13043478260869]
# 2     10.135135  18.518519                [18.51851851851852, 72.5]
# 3     21.396396  35.185185   [35.18518518518518, 72.09302325581395]
# 4     32.657658  33.333333   [33.33333333333333, 95.83333333333334]
# ...         ...        ...                                      ...
# 1031  17.792793  30.555556  [30.555555555555557, 64.28571428571429]
# 1032  28.603604  41.666667              [41.66666666666667, 71.875]
# 1033  21.171171  34.259259   [34.25925925925926, 73.68421052631578]
# 1034  20.495495  34.259259  [34.25925925925926, 58.333333333333336]
# 1035  27.252252  33.333333   [33.33333333333333, 94.44444444444444]
#
#                                        pct_multilevel_3  \
# 0         [42.592592592592595, 82.5, 85.80246913580247]
# 1     [42.592592592592595, 64.13043478260869, 73.856...
# 2          [18.51851851851852, 72.5, 56.86274509803921]
# 3     [35.18518518518518, 72.09302325581395, 71.0743...
# 4         [33.33333333333333, 95.83333333333334, 100.0]
# ...                                                 ...
# 1031  [30.555555555555557, 64.28571428571429, 60.194...
# 1032     [41.66666666666667, 71.875, 66.66666666666666]
# 1033  [34.25925925925926, 73.68421052631578, 59.6491...
# 1034  [34.25925925925926, 58.333333333333336, 47.457...
# 1035  [33.33333333333333, 94.44444444444444, 73.9393...
#
#                                        pct_multilevel_4
# 0     [42.592592592592595, 82.5, 85.80246913580247, ...
# 1     [42.592592592592595, 64.13043478260869, 73.856...
# 2     [18.51851851851852, 72.5, 56.86274509803921, 6...
# 3     [35.18518518518518, 72.09302325581395, 71.0743...
# 4     [33.33333333333333, 95.83333333333334, 100.0, ...
# ...                                                 ...
# 1031  [30.555555555555557, 64.28571428571429, 60.194...
# 1032  [41.66666666666667, 71.875, 66.66666666666666,...
# 1033  [34.25925925925926, 73.68421052631578, 59.6491...
# 1034  [34.25925925925926, 58.333333333333336, 47.457...
# 1035  [33.33333333333333, 94.44444444444444, 73.9393...
#
# [1036 rows x 8 columns]

# %%
def to_list(list_of_strings):
    return list(map(float, list_of_strings.strip('][').split(', ')))

def treat_pcts(pcts):
    for col in ['pct_multilevel_2', 'pct_multilevel_3', 'pct_multilevel_4']:
        pcts[col] = pcts[col].apply(to_list)
    return pcts

def get_pcts(pcts, file):
    pcts_file = pcts[pcts['file name'] == file].iloc[0]
    return(pcts_file['pct_200'], pcts_file['pct_500'], pcts_file['pct_800'], pcts_file['pct_1600'],
            pcts_file['pct_multilevel_2'], pcts_file['pct_multilevel_3'], pcts_file['pct_multilevel_4'])

# %%
file_names = []
for year in ['2004']:
	path = '/Users/nicolas/Documents/ime/compmus/mestrado/maestro-dataset/' + year + '/*.wav'
	for file in glob.glob(path):
		file_names.append(file[:-4])

# %%
pcts = treat_pcts(pcts)

# %%
pcts[pcts['file name'] == file_names[0]].iloc[0]['pct_200']
# Out:
# 14.830827067669173

# %% [markdown]
# ### Tratando resultados FINAIS

# %% [markdown]
# ##### Parte 1: Carregando arquivos

# %%
results_cqt = pd.read_csv('./results_nohop/results_040820_stft_cqt.csv', sep=';')

# %%
results_stft  = pd.read_csv('results_250820_stft.csv', sep=';')

results_cqt  = pd.read_csv('results_nohop/results_270720_stft_cqt.csv', sep=';')
results_cqt2 = pd.read_csv('results_nohop/results_040820_stft_cqt.csv', sep=';')
results_cqt  = results_cqt.append(results_cqt2, ignore_index=True)
results_cqt  = results_cqt[results_cqt.representation == 'CQT']

results_swgm  = pd.read_csv('results_nohop/results_270720_swgm.csv', sep=';')
results_swgm  = pd.read_csv('results_nohop/results_040820_swgm.csv', sep=';')
results_swgm  = results_swgm.append(results_swgm, ignore_index=True)

results_ers = pd.read_csv('results_250820_ers_single.csv', sep=';')
results_ers_m = pd.read_csv('results_250820_ers_multi.csv', sep=';')
results_ers  = results_ers.append(results_ers_m, ignore_index=True)

# %%
all_results = results_ers.append(results_swgm, ignore_index=True)
all_results = all_results.append(results_stft, ignore_index=True)
all_results = all_results.append(results_cqt, ignore_index=True)
all_results = all_results.rename(columns={'timeit':'time (s)'})

# %%
all_results
# Out:
#                                                 file name representation  \
# 0       /Users/nicolas/Documents/ime/compmus/mestrado/...   economic 200
# 1       /Users/nicolas/Documents/ime/compmus/mestrado/...   economic 500
# 2       /Users/nicolas/Documents/ime/compmus/mestrado/...   economic 800
# 3       /Users/nicolas/Documents/ime/compmus/mestrado/...  economic 1600
# 4       /Users/nicolas/Documents/ime/compmus/mestrado/...   economic 200
# ...                                                   ...            ...
# 139533  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...            CQT
# 139534  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...            CQT
# 139535  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...            CQT
# 139536  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...            CQT
# 139537  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...            CQT
#
#         max res  time (s) pct refine
# 0           512  2.022312    14.8308
# 1           512  0.890472    23.2353
# 2           512  0.644616    29.0541
# 3           512  0.300379    42.5926
# 4          1024  2.032036    14.8308
# ...         ...       ...        ...
# 139533     2048  0.516854        NaN
# 139534     4096  0.533813        NaN
# 139535     8192  0.574394        NaN
# 139536    16384  0.667016        NaN
# 139537    32768  0.898142        NaN
#
# [139538 rows x 5 columns]

# %% [markdown]
# agora: pegar média por arquivo (o experimento é repetido 5x por arquivo)

# %%
res = all_results.groupby(['file name', 'representation', 'max res'], as_index=False).mean()

# %%
res
# Out:
#                                                file name representation  \
# 0      ../../../maestro-dataset/2004/MIDI-Unprocessed...           STFT
# 1      ../../../maestro-dataset/2004/MIDI-Unprocessed...           STFT
# 2      ../../../maestro-dataset/2004/MIDI-Unprocessed...           STFT
# 3      ../../../maestro-dataset/2004/MIDI-Unprocessed...           STFT
# 4      ../../../maestro-dataset/2004/MIDI-Unprocessed...           STFT
# ...                                                  ...            ...
# 65277  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 65278  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 65279  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 65280  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 65281  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
#
#        max res  time (s)
# 0          512  0.038130
# 1         1024  0.023332
# 2         2048  0.048587
# 3         4096  0.080409
# 4         8192  0.221964
# ...        ...       ...
# 65277     2048  0.664767
# 65278     4096  0.769169
# 65279     8192  0.734498
# 65280    16384  0.848566
# 65281    32768  1.034848
#
# [65282 rows x 4 columns]

# %%
our_16 = res[res['representation'] == 'economic 1600']
our_16 = our_16.groupby(['max res']).mean()

our_8 = res[res['representation'] == 'economic 800']
our_8 = our_8.groupby(['max res']).mean()

our_5 = res[res['representation'] == 'economic 500']
our_5 = our_5.groupby(['max res']).mean()

our_2 = res[res['representation'] == 'economic 200']
our_2 = our_2.groupby(['max res']).mean()

our_2lvl = res[res['representation'] == 'economic 2 lvl']
our_2lvl = our_2lvl.groupby(['max res']).mean()

our_3lvl = res[res['representation'] == 'economic 3 lvl']
our_3lvl = our_3lvl.groupby(['max res']).mean()

our_4lvl = res[res['representation'] == 'economic 4 lvl']
our_4lvl = our_4lvl.groupby(['max res']).mean()

# %%
stft = res[res['representation'] == 'STFT']
stft = stft.groupby(['max res']).mean()

cqt = res[res['representation'] == 'CQT']
cqt = cqt.groupby(['max res']).mean()

swgm = res[res['representation'] == 'SWGM']
swgm = swgm.groupby(['max res']).mean()

# %%
all_results_costly = pd.read_csv('./results_pilot/all_results_costly_treated.csv')
lt = all_results_costly[all_results_costly['representation'] == 'LT']['time (s)'].to_numpy()
sls = all_results_costly[all_results_costly['representation'] == 'SLS']['time (s)'].to_numpy()

# %%
# Interpolando ultimo ponto p/ lt e sls

lt_forecast = [lt[-1], lt[-1] + ((lt[-1] - lt [-2]) / (16384-8192)) * 16384]
sls_forecast = [sls[-1], sls[-1] + ((sls[-1] - sls [-2]) / (16384-8192)) * 16384]

# %% [markdown]
# ##### Parte 2: Gráficos

# %%
resolutions = [512,1024,2048,4096,8192,16384,32768]

# %%
resolutions = [512,1024,2048,4096,8192,16384,32768]

plt.figure(figsize=[10,10])
plt.plot(resolutions, stft, label='STFT')
plt.plot(resolutions, cqt, label='CQT')
plt.plot(resolutions, swgm, label='SWGM')
plt.plot(resolutions, our_16, label='ERS - 1600x1600')
plt.plot(resolutions, our_3lvl, label='ERS - 3 levels')
plt.plot(resolutions[:-1], lt, label='Lukin-Todd', color='red')
plt.plot(resolutions[-2:], lt_forecast, '--', color='red')
plt.plot(resolutions[:-1], sls, label='Smoothed Local Sparsity', color='orange')
plt.plot(resolutions[-2:], sls_forecast, '--', color='orange')


plt.xlabel('Resolution')
plt.ylabel('Execution time (s)')
plt.title('Computing cost comparison')

plt.legend(fontsize='x-large')

# %%
plt.figure(figsize=[10,10])
plt.plot(resolutions, stft, label='STFT')
plt.plot(resolutions, cqt, label='CQT')
plt.plot(resolutions, swgm, label='SWGM')
plt.plot(resolutions, our_16, label='ERS - 1600x1600')
plt.plot(resolutions, our_3lvl, label='ERS - 3 levels')
plt.plot(resolutions[:-1], lt, label='Lukin-Todd', color='red')
plt.plot(resolutions[-2:], lt_forecast, '--', color='red')
plt.plot(resolutions[:-1], sls, label='Smoothed Local Sparsity', color='orange')
plt.plot(resolutions[-2:], sls_forecast, '--', color='orange')


plt.xlabel('Resolution')
plt.ylabel('Execution time (s)')
plt.title('Computing cost comparison - log y-axis')

plt.yscale('log')

plt.legend(fontsize='medium', loc=0)

# %%
plt.figure(figsize=[10,10])
plt.plot(resolutions, stft, label='STFT')
plt.plot(resolutions, cqt, label='CQT')
plt.plot(resolutions, swgm, label='SWGM')
plt.plot(resolutions, our_16, label='ERS - 1600x1600')
plt.plot(resolutions, our_3lvl, label='ERS - 3 levels')

plt.xlabel('Resolution')
plt.ylabel('Execution time (s)')
plt.title('Computing cost comparison')

plt.legend(fontsize='x-large', loc=0)

# %%
plt.figure(figsize=[10,10])
plt.plot(resolutions, our_2, label='ERS - 200x200')
plt.plot(resolutions, our_5, label='ERS - 500x500')
plt.plot(resolutions, our_8, label='ERS - 800x800')
plt.plot(resolutions, our_16, label='ERS - 1600x1600')
plt.plot(resolutions, stft, label='STFT')
plt.plot(resolutions, cqt, label='CQT')

plt.xlabel('Resolution')
plt.ylabel('Execution time (s)')
plt.title('Computing cost comparison')


plt.legend(fontsize='x-large')

# %%
plt.figure(figsize=[10,10])
plt.plot(resolutions, our_2lvl, label='Our representation - 2 levels')
plt.plot(resolutions, our_3lvl, label='Our representation - 3 levels')
plt.plot(resolutions, our_4lvl, label='Our representation - 4 levels')
plt.plot(resolutions, our_16, label='Our representation - 1600x1600')
plt.plot(resolutions, our_8, label='Our representation - 800x800')
plt.plot(resolutions, our_5, label='Our representation - 500x500')
plt.plot(resolutions, our_2, label='Our representation - 200x200')

plt.xlabel('Resolution')
plt.ylabel('Execution time (ms)')
plt.title('Computing cost comparison')

plt.legend(fontsize='x-large')

# %%
our_8 = res[res['representation'] == 'economic 800']
our_8.boxplot(column='time (s)', by='max res')

# %%
results.head()
# Out:
#                                            file name representation  max res  \
# 0  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 200      512
# 1  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 500      512
# 2  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800      512
# 3  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...  economic 1600      512
# 4  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 200     1024
#
#    time (s)          pct refine
# 0  1.718975   9.078947368421053
# 1  0.794866  17.549019607843135
# 2  0.570447   22.97297297297297
# 3  0.268805  38.888888888888886
# 4  1.657826   9.078947368421053

# %%
pcts = results.drop(['time (s)'], axis=1)

# %%
reps = ['economic 200', 'economic 500', 'economic 800', 'economic 1600']
pcts = pcts.query("representation in ['economic 200', 'economic 500', 'economic 800', 'economic 1600']")
pcts['pct refine'].astype(float)

# %%
np.sqrt(pcts.groupby('representation').var()['pct refine'])
# Out:
# representation
# economic 1600    11.358581
# economic 200      7.819878
# economic 500      9.359160
# economic 800      9.881432
# Name: pct refine, dtype: float64

# %%
results = pd.read_csv('results_new_180720.csv', sep=';')
# results.columns = ['file name', 'representation', 'timeit']
# results['time (ms)'] = results['timeit'].apply(get_time)
# results['std dev (ms)'] = results['timeit'].apply(get_std_dev)
# return results.drop(['timeit'], axis=1)

# %% [markdown]
# #### ler csv, formatar dados, passar todos os tempos pra ms, fazer boxplots

# %%
def get_time(timeit):
    mean = timeit.split(' ')[0]
    unit = timeit.split(' ')[1]
    if unit == 's':
         return float(mean)*1000
    return float(mean)

def get_std_dev(timeit):
    std_dev = timeit.split(' ')[3]
    unit = timeit.split(' ')[4]
    if unit == 'µs':
         return float(std_dev)/1000
    return float(std_dev)

def get_time_costly(timeit):
    time_in_sec = 0
    time = timeit.split('±')[0]
    for unit in time.split(' '):
        if unit == '':
            continue
        if unit[-1] == 'h':
            time_in_sec += float(unit[:-1]) * 60 * 60
        elif unit[-1] == 'n':
            time_in_sec += float(unit[:-3]) * 60
        elif unit[-1] == 's':
            time_in_sec += float(unit[:-1])
    return time_in_sec

# %%
def treat_results(file_name):
    results = pd.read_csv(file_name, sep=';')
    results['time (ms)'] = results['timeit'].apply(get_time)
    results['std dev (ms)'] = results['timeit'].apply(get_std_dev)
    return results.drop(['timeit'], axis=1)

def treat_results_costly(file_name):
    results = pd.read_csv(file_name, sep=';', header=None)
    results.columns = ['file name', 'representation', 'timeit']
    results['time (s)'] = results['timeit'].apply(get_time_costly)
    return results.drop(['timeit'], axis=1)

# %%
results = treat_results('./results_new_180720.csv')

# %%
# all_results_costly = pd.DataFrame(columns=['file name', 'representation', 'resolution', 'time (s)'])

# for res in [512, 1024, 2048, 4096, 8192, 16384]:
#     file = './results_pilot/all_results_costly_treated.csv''
#     file = 'results_costly' + str(res) + '.csv'
#     results = treat_results_costly(file)
#     results['resolution'] = res
#     all_results_costly = all_results_costly.append(results)

# %%
all_results_costly = pd.read_csv('./results_pilot/all_results_costly_treated.csv')

# %% [markdown]
# Groupby representation and make boxplots

# %%
cqt = results[results['representation'] == 'CQT']
cqt = cqt.drop('std dev (ms)', axis=1)

# %%
cqt.head()
# Out:
#                                             file name representation  max res  \
# 1   /Volumes/HD-NICO/vaio-backup/Documents/ime/com...            CQT      512
# 10  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...            CQT     1024
# 19  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...            CQT     2048
# 28  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...            CQT     4096
# 37  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...            CQT     8192
#
#     n_fft pct refine  time (ms)
# 1     NaN        NaN      582.0
# 10    NaN        NaN      532.0
# 19    NaN        NaN      564.0
# 28    NaN        NaN      558.0
# 37    NaN        NaN      589.0

# %%
plt.figure(figsize=[10,10])
cqt.boxplot(column='time (ms)', by='max res')

# %%
our = results[results['representation'] == 'economic 800']
our = our.drop('std dev (ms)', axis=1)

# %%
plt.figure(figsize=[10,10])
our.boxplot(column='time (ms)', by='max res')

# %%
our = all_results[all_results['representation'] == 'economic 500']
our = our.drop('std dev (ms)', axis=1)

swgm = all_results[all_results['representation'] == 'SWGM']
swgm = swgm.drop('std dev (ms)', axis=1)

stft = all_results[all_results['representation'] == 'STFT']
stft = stft.drop('std dev (ms)', axis=1)

cqt = all_results[all_results['representation'] == 'CQT']
cqt = cqt.drop('std dev (ms)', axis=1)

# %%
plt.figure(figsize=[10,10])
ax = swgm.boxplot(by='resolution', return_type='axes')
ax = our.boxplot(by='resolution', ax=ax)
ax = cqt.boxplot(by='resolution', ax=ax)
ax = stft.boxplot(by='resolution', ax=ax)
# Out:
# /Users/nicolas/Library/Python/3.7/lib/python/site-packages/pandas/plotting/_matplotlib/boxplot.py:375: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes
#   **kwds,
# /Users/nicolas/Library/Python/3.7/lib/python/site-packages/pandas/plotting/_matplotlib/boxplot.py:375: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes
#   **kwds,
# /Users/nicolas/Library/Python/3.7/lib/python/site-packages/pandas/plotting/_matplotlib/boxplot.py:375: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes
#   **kwds,

# %%
our = results[results['representation'] == 'economic 800']
our = our.drop(['std dev (ms)', 'n_fft'], axis=1)
our = our.groupby(['max res']).mean()

swgm = results[results['representation'] == 'SWGM']
swgm = swgm.drop(['std dev (ms)', 'n_fft'], axis=1)
swgm = swgm.groupby(['max res']).mean()

stft = results[results['representation'] == 'STFT']
stft = stft.drop(['std dev (ms)', 'n_fft'], axis=1)
stft = stft.groupby(['max res']).mean()

cqt = results[results['representation'] == 'CQT']
cqt = cqt.drop(['std dev (ms)', 'n_fft'], axis=1)
cqt = cqt.groupby(['max res']).mean()

# %%
resolutions = [512, 1024, 2048, 4096, 8192, 16384, 32768]

# %%
plt.figure(figsize=[10,10])
plt.plot(resolutions, our, label='Our economic representation')
plt.plot(resolutions, cqt, label='CQT')
# plt.plot(resolutions, swgm, label='SWGM')
plt.plot(resolutions, stft, label='STFT')

plt.xlabel('Resolution')
plt.ylabel('Execution time (ms)')

plt.legend(fontsize='x-large')

# %%
our_8 = results[results['representation'] == 'economic 800']
our_8 = our_8.drop(['std dev (ms)', 'n_fft'], axis=1)
our_8 = our_8.groupby(['max res']).mean()

our_5 = results[results['representation'] == 'economic 500']
our_5 = our_5.drop(['std dev (ms)', 'n_fft'], axis=1)
our_5 = our_5.groupby(['max res']).mean()

our_2 = results[results['representation'] == 'economic 200']
our_2 = our_2.drop(['std dev (ms)', 'n_fft'], axis=1)
our_2 = our_2.groupby(['max res']).mean()

# %%
plt.figure(figsize=[10,10])
plt.plot(resolutions, our_2, label='Our economic representation - 200x200')
plt.plot(resolutions, our_5, label='Our economic representation - 500x500')
plt.plot(resolutions, our_8, label='Our economic representation - 800x800')

plt.xlabel('Resolution')
plt.ylabel('Execution time (ms)')

plt.legend(fontsize='x-large')

# %%
our_2lvl = results[results['representation'] == 'economic 2 lvl']
our_2lvl = our_2lvl.drop(['std dev (ms)', 'n_fft'], axis=1)
our_2lvl = our_2lvl.groupby(['max res']).mean()

our_3lvl = results[results['representation'] == 'economic 3 lvl']
our_3lvl = our_3lvl.drop(['std dev (ms)', 'n_fft'], axis=1)
our_3lvl = our_3lvl.groupby(['max res']).mean()

our_4lvl = results[results['representation'] == 'economic 4 lvl']
our_4lvl = our_4lvl.drop(['std dev (ms)', 'n_fft'], axis=1)
our_4lvl = our_4lvl.groupby(['max res']).mean()

# %%
441000/512
# Out:
# 861.328125

# %%
plt.figure(figsize=[10,10])
plt.plot(resolutions, our_2lvl, label='Our economic representation - 2 levels')
plt.plot(resolutions, our_3lvl, label='Our economic representation - 3 levels')
plt.plot(resolutions, our_4lvl, label='Our economic representation - 4 levels')
plt.plot(resolutions, our_8, label='Our economic representation - 1 level - 800x800')


plt.xlabel('Resolution')
plt.ylabel('Execution time (ms)')

plt.legend(fontsize='x-large')

# %%
resolutions = resolutions[:-1]
lt = all_results_costly[all_results_costly['representation'] == 'LT']['time (s)']
sls = all_results_costly[all_results_costly['representation'] == 'SLS']['time (s)']

# %%
plt.figure(figsize=[10,10])
plt.plot(resolutions, lt, label='Lukin-Todd')
plt.plot(resolutions, sls, label='Smoothed Local Sparsity')

plt.xlabel('Resolution')
plt.ylabel('Execution time (s)')

plt.legend(fontsize='x-large')

# %%
plt.figure(figsize=[10,10])
plt.plot(resolutions, lt, label='Lukin-Todd')
plt.plot(resolutions, sls, label='Smoothed Local Sparsity')
plt.plot(resolutions, our_8[:-1] / 1000, label='Our economic representation')

plt.xlabel('Resolution')
plt.ylabel('Execution time (s)')
plt.yscale('log')

plt.legend(fontsize='x-large')

# %% [markdown]
# checar pct pra nossa representação "estressada"

# %%
results.head()
# Out:
#                                            file name representation  max res  \
# 0  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...           STFT      512
# 1  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...            CQT      512
# 2  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...           SWGM      512
# 3  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 200      512
# 4  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 500      512
#
#    n_fft          pct refine  time (ms)  std dev (ms)
# 0    NaN                 NaN       38.7         0.545
# 1    NaN                 NaN      582.0       108.000
# 2    NaN                 NaN      122.0         4.050
# 3  512.0  10.508149568552252     2110.0       298.000
# 4  512.0   19.50980392156863     1060.0       133.000

# %%
our_8 = results[results['representation'] == 'economic 800']

# %%
our_8[pct]
# Out:
#                                              file name representation  \
# 5    /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 14   /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 23   /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 32   /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 41   /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 50   /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 59   /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 68   /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 77   /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 86   /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 95   /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 104  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 113  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 122  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 131  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 140  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 149  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 158  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 167  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 176  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 185  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 194  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 203  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 212  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 221  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 230  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 239  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 248  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 257  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 266  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 275  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 284  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 293  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 302  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
# 311  /Volumes/HD-NICO/vaio-backup/Documents/ime/com...   economic 800
#
#      max res  n_fft          pct refine  time (ms)  std dev (ms)
# 5        512  512.0   24.54954954954955      859.0         39.90
# 14      1024  512.0   24.54954954954955      908.0         22.90
# 23      2048  512.0   24.54954954954955      795.0          7.00
# 32      4096  512.0   24.54954954954955     1310.0        148.00
# 41      8192  512.0   24.54954954954955      813.0         24.90
# 50     16384  512.0   24.54954954954955      878.0         40.20
# 59     32768  512.0   24.54954954954955     1400.0        330.00
# 68       512  512.0  16.666666666666664      709.0          6.82
# 77      1024  512.0  16.666666666666664      803.0          8.82
# 86      2048  512.0  16.666666666666664      747.0         56.40
# 95      4096  512.0  16.666666666666664      835.0         68.40
# 104     8192  512.0  16.666666666666664      827.0        120.00
# 113    16384  512.0  16.666666666666664      772.0         53.50
# 122    32768  512.0  16.666666666666664      675.0          9.29
# 131      512  512.0   14.63963963963964      821.0        118.00
# 140     1024  512.0   14.63963963963964      737.0         60.80
# 149     2048  512.0   14.63963963963964      712.0          4.21
# 158     4096  512.0   14.63963963963964      745.0         48.40
# 167     8192  512.0   14.63963963963964      734.0         53.00
# 176    16384  512.0   14.63963963963964      750.0         22.20
# 185    32768  512.0   14.63963963963964      676.0         14.10
# 194      512  512.0   31.08108108108108      916.0          6.38
# 203     1024  512.0   31.08108108108108      938.0         10.50
# 212     2048  512.0   31.08108108108108      983.0         26.50
# 221     4096  512.0   31.08108108108108     1130.0         48.40
# 230     8192  512.0   31.08108108108108     1070.0        162.00
# 239    16384  512.0   31.08108108108108      992.0         24.10
# 248    32768  512.0   31.08108108108108      865.0          1.80
# 257      512  512.0   36.93693693693694      977.0         17.90
# 266     1024  512.0   36.93693693693694      981.0         16.70
# 275     2048  512.0   36.93693693693694      996.0         14.40
# 284     4096  512.0   36.93693693693694     1460.0        315.00
# 293     8192  512.0   36.93693693693694     1340.0        362.00
# 302    16384  512.0   36.93693693693694     1220.0        172.00
# 311    32768  512.0   36.93693693693694     1080.0         18.00

# %%
our_8['pct refine'].max()
# Out:
# '36.93693693693694'

# %% [markdown]
# ### New results - final ERS

# %%
other = pd.read_csv('./results_final_ers/results_others.csv', sep=';')
single = pd.read_csv('./results_final_ers/results_ers_single.csv', sep=';')
multi = pd.read_csv('./results_final_ers/results_ers_multi.csv', sep=';')

res = other.append(single, ignore_index=True)
res = res.append(multi, ignore_index=True)

# %%
res.drop('pct refine', axis=1, inplace=True)

# %%
ers_16 = res[res['representation'] == 'ers 1600']
ers_16 = ers_16.groupby(['max res']).mean()

ers_8 = res[res['representation'] == 'ers 800']
ers_8 = ers_8.groupby(['max res']).mean()

ers_5 = res[res['representation'] == 'ers 500']
ers_5 = ers_5.groupby(['max res']).mean()

ers_2 = res[res['representation'] == 'ers 200']
ers_2 = ers_2.groupby(['max res']).mean()

ers_2lvl = res[res['representation'] == 'ers 2 lvl']
ers_2lvl = ers_2lvl.groupby(['max res']).mean()

ers_3lvl = res[res['representation'] == 'ers 3 lvl']
ers_3lvl = ers_3lvl.groupby(['max res']).mean()

ers_4lvl = res[res['representation'] == 'ers 4 lvl']
ers_4lvl = ers_4lvl.groupby(['max res']).mean()

# %%
stft = res[res['representation'] == 'STFT']
stft = stft.groupby(['max res']).mean()

cqt = res[res['representation'] == 'CQT']
cqt = cqt.groupby(['max res']).mean()

swgm = res[res['representation'] == 'SWGM']
swgm = swgm.groupby(['max res']).mean()

# %%
all_results_costly = pd.read_csv('./results_pilot/all_results_costly_treated.csv')
lt = all_results_costly[all_results_costly['representation'] == 'LT']['time (s)'].to_numpy()
sls = all_results_costly[all_results_costly['representation'] == 'SLS']['time (s)'].to_numpy()

# Interpolando ultimo ponto p/ lt e sls
lt_forecast = [lt[-1], lt[-1] + ((lt[-1] - lt [-2]) / (16384-8192)) * 16384]
sls_forecast = [sls[-1], sls[-1] + ((sls[-1] - sls [-2]) / (16384-8192)) * 16384]

# %%
resolutions = [512,1024,2048,4096,8192,16384,32768]

plt.figure(figsize=[8,8])
plt.plot(resolutions, stft, label='STFT')
plt.plot(resolutions, cqt, label='CQT')
plt.plot(resolutions, swgm, label='SWGM')
plt.plot(resolutions, ers_16, label='ERS - 1600x1600')
plt.plot(resolutions, ers_3lvl, label='ERS - 3 levels')
plt.plot(resolutions[:-1], lt, label='Lukin-Todd', color='red')
plt.plot(resolutions[-2:], lt_forecast, '--', color='red')
plt.plot(resolutions[:-1], sls, label='Smoothed Local Sparsity', color='orange')
plt.plot(resolutions[-2:], sls_forecast, '--', color='orange')


plt.xlabel('Resolution (window size)')
plt.ylabel('Execution time (s)')
plt.title('Computing cost comparison')

plt.legend(fontsize='x-large')

# %%
plt.figure(figsize=[8,8])
plt.plot(resolutions, stft, label='STFT')
plt.plot(resolutions, cqt, label='CQT')
plt.plot(resolutions, swgm, label='SWGM')
plt.plot(resolutions, ers_16, label='ERS - 1600x1600')
plt.plot(resolutions, ers_3lvl, label='ERS - 3 levels')
plt.plot(resolutions[:-1], lt, label='Lukin-Todd', color='red')
plt.plot(resolutions[-2:], lt_forecast, '--', color='red')
plt.plot(resolutions[:-1], sls, label='Smoothed Local Sparsity', color='orange')
plt.plot(resolutions[-2:], sls_forecast, '--', color='orange')


plt.xlabel('Resolution (window size)')
plt.ylabel('Execution time (s)')
plt.title('Computing cost comparison - log y-axis')

plt.yscale('log')

plt.legend(fontsize='medium', loc=0)

# %%
plt.figure(figsize=[8,8])
plt.plot(resolutions, stft, label='STFT')
plt.plot(resolutions, cqt, label='CQT')
plt.plot(resolutions, swgm, label='SWGM')
plt.plot(resolutions, ers_16, label='ERS - 1600x1600')
plt.plot(resolutions, ers_3lvl, label='ERS - 3 levels')

plt.xlabel('Resolution (window size)')
plt.ylabel('Execution time (s)')
plt.title('Computing cost comparison')

plt.legend(fontsize='x-large', loc=0)

# %%
plt.figure(figsize=[8,8])
plt.plot(resolutions, ers_2, label='ERS - 200x200')
plt.plot(resolutions, ers_5, label='ERS - 500x500')
plt.plot(resolutions, ers_8, label='ERS - 800x800')
plt.plot(resolutions, ers_16, label='ERS - 1600x1600')
plt.plot(resolutions, stft, label='STFT')
plt.plot(resolutions, cqt, label='CQT')

plt.xlabel('Resolution (window size)')
plt.ylabel('Execution time (s)')
plt.title('Computing cost comparison')


plt.legend(fontsize='x-large')

# %%
plt.figure(figsize=[8,5])
plt.plot(resolutions, ers_2lvl, label='ERS - 2 levels')
plt.plot(resolutions, ers_3lvl, label='ERS - 3 levels')
plt.plot(resolutions, ers_4lvl, label='ERS - 4 levels')
plt.plot(resolutions, ers_16, label='ERS - 1600x1600')
plt.plot(resolutions, ers_8, label='ERS - 800x800')
plt.plot(resolutions, ers_5, label='ERS - 500x500')
plt.plot(resolutions, ers_2, label='ERS - 200x200')

plt.xlabel('Resolution (window size)')
plt.ylabel('Execution time (s)')
plt.title('Computing cost comparison')

plt.legend(fontsize='x-large')

# %%
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=[20,5])
i=0
# for representation in ['ers 1600', 'ers 800', 'ers 500', 'ers 200']:

df = res[res['representation'] == 'ers 1600']
df.boxplot(by='max res', ax=axes[0])
axes[0].set_title('Execution times for ERS - 1600x1600')
axes[0].set_xlabel('Resolution (window size)')
axes[0].set_ylabel('Execution time (s)')
axes[0].set_ylim([0.2,1.4])


df = res[res['representation'] == 'ers 800']
df.boxplot(by='max res', ax=axes[1])
axes[1].set_title('Execution times for ERS - 800x800')
axes[1].set_xlabel('Resolution (window size)')
# axes[1].set_ylabel('Execution time (s)')


df = res[res['representation'] == 'ers 500']
df.boxplot(by='max res', ax=axes[2])
axes[2].set_title('Execution times for ERS - 500x500')
axes[2].set_xlabel('Resolution (window size)')
# axes[2].set_ylabel('Execution time (s)')

df = res[res['representation'] == 'ers 200']
df.boxplot(by='max res', ax=axes[3])
axes[3].set_title('Execution times for ERS - 200x200')
axes[3].set_xlabel('Resolution (window size)')
# axes[3].set_ylabel('Execution time (s)')
# Out:
# Text(0.5, 0, 'Resolution (window size)')

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=[15,5])
i=0
# for representation in ['ers 1600', 'ers 800', 'ers 500', 'ers 200']:

df = res[res['representation'] == 'ers 2 lvl']
df.boxplot(by='max res', ax=axes[0])
axes[0].set_title('Execution times for ERS - 2 levels')
axes[0].set_xlabel('Resolution (window size)')
axes[0].set_ylim([0.0,4.0])
axes[0].set_ylabel('Execution time (s)')

df = res[res['representation'] == 'ers 3 lvl']
df.boxplot(by='max res', ax=axes[1])
axes[1].set_title('Execution times for ERS - 3 levels')
axes[1].set_xlabel('Resolution (window size)')
# axes[1].set_ylabel('Execution time (s)')

df = res[res['representation'] == 'ers 4 lvl']
df.boxplot(by='max res', ax=axes[2])
axes[2].set_title('Execution times for ERS - 4 levels')
axes[2].set_xlabel('Resolution (window size)')
# axes[2].set_ylabel('Execution time (s)')
# Out:
# /Users/nicolas/Library/Python/3.7/lib/python/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# Text(0.5, 0, 'Resolution (window size)')

# %%
resolutions = [512,1024,2048,4096,8192,16384,32768]

plt.figure(figsize=[8,8])
plt.plot(resolutions, stft, label='STFT')
plt.plot(resolutions, cqt, label='CQT')
# plt.plot(resolutions, swgm, label='SWGM')
plt.plot(resolutions, ers_16, label='ERS - 1600x1600')
plt.plot(resolutions, ers_8, label='ERS - 800x800')
plt.plot(resolutions, ers_2, label='ERS - 200x200')
plt.plot(resolutions, ers_2lvl, label='ERS - 2 levels')
plt.plot(resolutions, ers_3lvl, label='ERS - 3 levels')

plt.xlabel('Resolution (window size)')
plt.ylabel('Execution time (s)')
plt.title('Computing cost comparison')

plt.legend(fontsize='x-large')
