# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import sys
sys.path.insert(0, '../scripts')

import stft_zoom, display, detect_musical_regions
from util import *
import mappings
import pickle
import PIL
import IPython.display
from classes import SingleResSpectrogram, MultiResSpectrogram
from aug_density_map import *
from mappings import *
import detect_musical_regions
from classes import MultiResSpectrogram, SingleResSpectrogram
# Out:
# /Library/Python/3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /Library/Python/3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit

# %% [markdown]
# ### Plot 1 - Representação da solução multinivel

# %%
y, sr = librosa.load('../../midi-experiment/notebooks/testee.wav', sr=44100)
spec = np.abs(librosa.stft(y, n_fft=512, hop_length=512))

# %%
plt.figure(figsize=[8,8])
librosa.display.specshow(librosa.amplitude_to_db(spec, ref=np.max), sr=44100,  hop_length=512, y_axis='log', x_axis='time')

# %%
time_span = [0,len(y)/sr]
_, y_axis = stft_zoom.get_axes_values(sr, 0, time_span, spec.shape) 
shannon, renyi = mappings.extract_features(spec, [800,800], n_fft=512, hop_size=512, sr=sr, fft_freqs=y_axis)

# %%
plt.figure(figsize=[8,8])
plt.imshow(shannon * renyi, aspect='auto', origin='lower')
# plt.colorbar()

# %%
n_fft=512
hop_size=512
model = pickle.load(open('./renyi_shannon_prollharm_800.sav', 'rb'))
kernel = [800,800]
pct=50
res = 5


spec = np.abs(librosa.stft(y, n_fft=n_fft, hop_length=hop_size))
time_span = [0,len(y)/sr]
x_axis, y_axis = stft_zoom.get_axes_values(sr, 0, time_span, spec.shape)
base_spec = SingleResSpectrogram(spec, x_axis, y_axis)
multires_spec = MultiResSpectrogram(base_spec)
indices, original_shape = detect_musical_regions.detect_musical_regions(model, spec, kernel=kernel, mode='pct', pct_or_threshold=pct, n_fft=n_fft, hop_size=hop_size)
to_be_refined = detect_musical_regions.musical_regions_to_ranges(indices, original_shape, x_axis, y_axis, kernel, n_fft=n_fft, hop_size=hop_size)

stft_zoom.set_signal_bank(y,kernel)

for subregion in to_be_refined[:3]:
    freq_range = subregion[0]
    time_range = subregion[1]
    spec_zoom, x_axis, y_axis, new_sr, window_size, hop_size = stft_zoom.stft_zoom(y, freq_range, time_range, sr=sr, original_window_size=n_fft, k=res)
    refined_subspec = SingleResSpectrogram(spec_zoom, x_axis, y_axis)
    multires_spec.insert_zoom(multires_spec.base_spec, refined_subspec, zoom_level=1)

# %%
plt.figure(figsize=[8,8])
librosa.display.specshow(librosa.amplitude_to_db(multires_spec.generate_visualization(), ref=np.max), y_axis='log')

# %%
def our_solution(y, res, kernel, model, pct, sr=44100, n_fft=512, hop_size=128):
    spec = np.abs(librosa.stft(y, n_fft=n_fft, hop_length=hop_size))
    time_span = [0,len(y)/sr]
    x_axis, y_axis = stft_zoom.get_axes_values(sr, 0, time_span, spec.shape) 
    base_spec = SingleResSpectrogram(spec, x_axis, y_axis)
    multires_spec = MultiResSpectrogram(base_spec)
    indices, original_shape = detect_musical_regions.detect_musical_regions(model, spec, kernel=kernel, mode='pct', pct_or_threshold=pct, n_fft=n_fft, hop_size=hop_size)
    to_be_refined = detect_musical_regions.musical_regions_to_ranges(indices, original_shape, x_axis, y_axis, kernel, n_fft=n_fft, hop_size=hop_size)

    stft_zoom.set_signal_bank(y,kernel)

    for subregion in to_be_refined:
        freq_range = subregion[0]
        time_range = subregion[1]
        spec_zoom, x_axis, y_axis, new_sr, window_size, hop_size = stft_zoom.stft_zoom(y, freq_range, time_range, sr=sr, original_window_size=n_fft, k=res)
        refined_subspec = SingleResSpectrogram(spec_zoom, x_axis, y_axis)
        multires_spec.insert_zoom(multires_spec.base_spec, refined_subspec, zoom_level=1)
        
    return multires_spec

def our_solution_multilevel(y, res_list, kernel_list, model, pct_list, sr=44100, n_fft=512, hop_size=128):
    o_n_fft = n_fft
    o_hop_size = hop_size
    spec = np.abs(librosa.stft(y, n_fft=n_fft, hop_length=hop_size))
    time_span = [0,len(y)/sr]
    x_axis, y_axis = stft_zoom.get_axes_values(sr, 0, time_span, spec.shape) 
    base_spec = SingleResSpectrogram(spec, x_axis, y_axis)
    multires_spec = MultiResSpectrogram(base_spec)
    
    kernel = kernel_list[0]
    indices, original_shape = detect_musical_regions.detect_musical_regions(model, spec, kernel=kernel, mode='pct', pct_or_threshold=pct_list[0], n_fft=n_fft, hop_size=hop_size)
    to_be_refined = detect_musical_regions.musical_regions_to_ranges(indices, original_shape, x_axis, y_axis, kernel, n_fft=n_fft, hop_size=hop_size)

    stft_zoom.set_signal_bank(y,kernel)
    
#     print(kernel, len(to_be_refined))
    for subregion in to_be_refined:
        freq_range = subregion[0]
        time_range = subregion[1]
        spec_zoom, x_axis, y_axis, new_sr, window_size, hop_size = stft_zoom.stft_zoom(y, freq_range, time_range, sr=sr, original_window_size=n_fft, k=res_list[0])
        refined_subspec = SingleResSpectrogram(spec_zoom, x_axis, y_axis, n_fft=window_size, hop_size=hop_size, sr=new_sr)
        multires_spec.insert_zoom(multires_spec.base_spec, refined_subspec, zoom_level=1)
        
    i = 1
    for kernel in kernel_list[1:]:
        i += 1
#         print(res_list[i-1])
        if i == 2:
            spec_list = multires_spec.first_zoom
        elif i == 3:
            spec_list = multires_spec.second_zoom
        elif i == 4:
            spec_list = multires_spec.third_zoom

        to_be_further_refined = []
        for spec_zoom in spec_list:
            spec        = np.array(spec_zoom.spec, dtype=float)
            x_axis      = spec_zoom.x_axis
            y_axis      = spec_zoom.y_axis
            sr          = spec_zoom.sr
            window_size = spec_zoom.n_fft
            hop_size    = spec_zoom.hop_size
            
            if len(y_axis) == 1 or len(x_axis) == 1:
                continue
            
            indices, original_shape = detect_musical_regions.detect_musical_regions(model, spec, mode='pct', pct_or_threshold=pct_list[i-1], kernel=kernel, n_fft=window_size, hop_size=hop_size, sr=sr, y_axis=y_axis)
            to_be_further_refined = to_be_further_refined + detect_musical_regions.musical_regions_to_ranges(indices, original_shape, x_axis, y_axis, kernel, sr=sr, hop_size=hop_size)

        sr = 44100
        hop_size = o_hop_size
        n_fft = o_n_fft
#         print(kernel, len(to_be_further_refined))
        for subregion in to_be_further_refined:
            freq_range = subregion[0]
            time_range = subregion[1]
            
            # aqui: mudança no slice de tempo pra manter o número de frames com rel ao zoom anterior
            time_span = time_range[1] - time_range[0]
            new_time_span = (res_list[i-1]/res_list[i-2]) * time_span # res_list[i-1]/res_list[i-2] é o fator multiplicador desse nivel com rel ao ultimo 
            time_range[0] -= (new_time_span - time_span) / 2
            time_range[1] += (new_time_span - time_span) / 2

            spec_zoom, x_axis, y_axis, new_sr, window_size, hop_size = stft_zoom.stft_zoom_nobank(y, freq_range, time_range, sr=sr, original_window_size=n_fft, k=res_list[i-1])
            refined_subspec = SingleResSpectrogram(spec_zoom, x_axis, y_axis, n_fft=window_size, hop_size=hop_size, sr=new_sr)
            multires_spec.insert_zoom(multires_spec.base_spec, refined_subspec, zoom_level=i, normalize=False)
    return multires_spec

# %%
res    = 2
kernel = [800,800]
model  = model_800 = pickle.load(open('./renyi_shannon_prollharm_800.sav', 'rb'))
pct    = 1
n_fft  = 512
hop_size = n_fft

spec = np.abs(librosa.stft(y, n_fft=n_fft, hop_length=hop_size))
time_span = [0,len(y)/sr]
x_axis, y_axis = stft_zoom.get_axes_values(sr, 0, time_span, spec.shape) 
base_spec = SingleResSpectrogram(spec, x_axis, y_axis)
multires_spec = MultiResSpectrogram(base_spec)
indices, original_shape = detect_musical_regions.detect_musical_regions(model, spec, kernel=kernel, mode='pct', pct_or_threshold=pct, n_fft=n_fft, hop_size=hop_size)
to_be_refined = detect_musical_regions.musical_regions_to_ranges(indices, original_shape, x_axis, y_axis, kernel, n_fft=n_fft, hop_size=hop_size)

# %%
to_be_refined
# Out:
# [([344.53125, 602.9296875], [3.1997699242298543, 4.012773629777114])]

# %%
time_step = 512/44100
for subregion in to_be_refined:
    freq_range = subregion[0]
    time_range = subregion[1]
    time_range[0] -= time_step/2
    time_range[1] += time_step/2
    if time_range[0] < 0:
        time_range[0] = 0

    spec_zoom, x_axis, y_axis, new_sr, window_size, hop_size = stft_zoom.stft_zoom_nobank(y, freq_range, time_range, sr=sr, original_window_size=n_fft, k=res)
    refined_subspec = SingleResSpectrogram(spec_zoom, x_axis, y_axis, n_fft=window_size, hop_size=hop_size, sr=new_sr)
    multires_spec.insert_zoom(multires_spec.base_spec, refined_subspec, zoom_level=1)

# %%
display.specshow(librosa.amplitude_to_db(spec_zoom, ref=np.max), x_axis, y_axis, y_axis='log', x_axis='time')

# %%
spec_zoom   = refined_subspec
spec        = np.array(spec_zoom.spec, dtype=float)
x_axis      = spec_zoom.x_axis
y_axis      = spec_zoom.y_axis
sr          = spec_zoom.sr
window_size = spec_zoom.n_fft
hop_size    = spec_zoom.hop_size

indices, original_shape = detect_musical_regions.detect_musical_regions(model_800, spec, mode='pct', pct_or_threshold=50, kernel=[400,400], n_fft=window_size, hop_size=hop_size, sr=sr, y_axis=y_axis)
to_be_further_refined = detect_musical_regions.musical_regions_to_ranges(indices, original_shape, x_axis, y_axis, [400,400], sr=sr, hop_size=hop_size)

# %%
shannon, renyi = mappings.extract_features(spec, [400,400], n_fft=window_size, hop_size=hop_size, sr=sr, fft_freqs=y_axis)

# %%
plt.figure(figsize=[8,4])
plt.imshow(shannon * renyi, aspect='auto', origin='lower')
plt.colorbar()

# %%
indices
# Out:
# array([3, 1, 2])

# %%
to_be_further_refined
# Out:
# [([387.59765625, 516.796875], [3.5830453725060383, 3.9895407754307493]),
#  ([301.46484375, 387.59765625], [3.5830453725060383, 3.9895407754307493]),
#  ([387.59765625, 516.796875], [3.188159946905591, 3.5946553498303015])]

# %%
sr = 44100
hop_size = 512
n_fft = 512
time_step = 512/44100
for subregion in to_be_further_refined[:1]:
    freq_range = subregion[0]
    time_range = subregion[1]
    time_range[0] -= time_step/2
    time_range[1] += time_step/2
    if time_range[0] < 0:
        time_range[0] = 0
    spec_zoom, x_axis, y_axis, new_sr, window_size, hop_size = stft_zoom.stft_zoom_nobank(y, freq_range, time_range, sr=sr, original_window_size=n_fft, k=4)               
    refined_subspec = SingleResSpectrogram(spec_zoom, x_axis, y_axis, n_fft=window_size, hop_size=hop_size, sr=new_sr)
    multires_spec.insert_zoom(multires_spec.base_spec, refined_subspec, zoom_level=1, normalize=False)

# %%
display.specshow(librosa.amplitude_to_db(spec_zoom, ref=np.max), x_axis, y_axis, y_axis='log', x_axis='time')

# %%
spec_zoom   = refined_subspec
spec        = np.array(spec_zoom.spec, dtype=float)
x_axis      = spec_zoom.x_axis
y_axis      = spec_zoom.y_axis
sr          = spec_zoom.sr
window_size = spec_zoom.n_fft
hop_size    = spec_zoom.hop_size

indices, original_shape = detect_musical_regions.detect_musical_regions(model_800, spec, mode='pct', pct_or_threshold=50, kernel=[200,200], n_fft=window_size, hop_size=hop_size, sr=sr, y_axis=y_axis)
to_be_further_refined = detect_musical_regions.musical_regions_to_ranges(indices, original_shape, x_axis, y_axis, [200,200], sr=sr, hop_size=hop_size)

# %%
shannon, renyi = mappings.extract_features(spec, [200,200], n_fft=window_size, hop_size=hop_size, sr=sr, fft_freqs=y_axis)

# %%
plt.figure(figsize=[8,4])
plt.imshow(shannon * renyi, aspect='auto', origin='lower')
plt.colorbar()

# %%
to_be_further_refined
# Out:
# [([391.42011834319527, 456.6568047337278],
#   [3.7689307363084166, 3.9778659867321102]),
#  ([391.42011834319527, 456.6568047337278],
#   [3.571492084524179, 3.780427334947872]),
#  ([347.92899408284023, 391.42011834319527],
#   [3.7689307363084166, 3.9778659867321102])]

# %%
sr = 44100
hop_size = 512
n_fft = 512

for subregion in to_be_further_refined[:1]:
    freq_range = subregion[0]
    time_range = subregion[1]
    spec_zoom, x_axis, y_axis, new_sr, window_size, hop_size = stft_zoom.stft_zoom_nobank(y, freq_range, time_range, sr=sr, original_window_size=n_fft, k=8)
    refined_subspec = SingleResSpectrogram(spec_zoom, x_axis, y_axis, n_fft=window_size, hop_size=hop_size, sr=new_sr)
    multires_spec.insert_zoom(multires_spec.base_spec, refined_subspec, zoom_level=1, normalize=False)

# %%
display.specshow(librosa.amplitude_to_db(spec_zoom, ref=np.max), x_axis, y_axis, y_axis='log', x_axis='time')

# %%
spec_zoom   = refined_subspec
spec        = np.array(spec_zoom.spec, dtype=float)
x_axis      = spec_zoom.x_axis
y_axis      = spec_zoom.y_axis
sr          = spec_zoom.sr
window_size = spec_zoom.n_fft
hop_size    = spec_zoom.hop_size

# %%
shannon, renyi = mappings.extract_features(spec, [100,100], n_fft=window_size, hop_size=hop_size, sr=sr, fft_freqs=y_axis)

# %%
plt.figure(figsize=[8,4])
plt.imshow(shannon * renyi, aspect='auto', origin='lower')
plt.colorbar()

# %% [markdown]
# ### Plot 2 - Normalização

# %%
def ers(y, res, kernel, model, pct, sr=44100, n_fft=512, hop_size=512, normalize=True, norm_fft=False):
    spec = np.abs(librosa.stft(y, n_fft=n_fft, hop_length=hop_size))
    if norm_fft:
        spec = normalize_subregion(spec, [0,len(y)*sr], [0,22050], y)
    time_span = [0,len(y)/sr]
    x_axis, y_axis = stft_zoom.get_axes_values(sr, 0, time_span, spec.shape)
    base_spec = SingleResSpectrogram(spec, x_axis, y_axis)
    multires_spec = MultiResSpectrogram(base_spec)
    indices, original_shape = detect_musical_regions.detect_musical_regions(model, spec, kernel=kernel, mode='pct', pct_or_threshold=pct, n_fft=n_fft, hop_size=hop_size)
    to_be_refined = detect_musical_regions.musical_regions_to_ranges(indices, original_shape, x_axis, y_axis, kernel, n_fft=n_fft, hop_size=hop_size)

    stft_zoom.set_signal_bank(y,kernel)

    for subregion in to_be_refined:
        freq_range = subregion[0]
        time_range = subregion[1]
        spec_zoom, x_axis, y_axis, new_sr, window_size, hop_size = stft_zoom.stft_zoom(y, freq_range, time_range, sr=sr, original_window_size=n_fft, k=res)

        if norm_fft:
            spec_zoom = normalize_subregion(spec_zoom, time_range, [y_axis[0], y_axis[-1]], y)
        
        refined_subspec = SingleResSpectrogram(spec_zoom, x_axis, y_axis)
        multires_spec.insert_zoom(multires_spec.base_spec, refined_subspec, zoom_level=1, normalize=normalize)
        
    return multires_spec

def energy_reference(y, time_range, freq_range, sr=44100):
    y_slice = y[math.floor(time_range[0] * sr): math.floor(time_range[1] * sr)]
    spec = np.fft.rfft(y_slice)
    freqs = np.fft.rfftfreq(len(y_slice), 1./sr)
    idx_start = find_nearest(freqs, freq_range[0])
    idx_stop = find_nearest(freqs, freq_range[1])
    return np.sum(np.abs(spec[idx_start:idx_stop])**2) * 2 / len(y_slice)

def normalize_subregion(spec_zoom, time_range, freq_range, y):
    energy_ref = energy_reference(y, time_range, freq_range)
    energy_old = np.sum(spec_zoom ** 2)
#     print(math.sqrt(energy_ref / energy_old))
    return math.sqrt(energy_ref / energy_old) * spec_zoom

# %%
y, sr = librosa.load('../../midi-experiment/notebooks/testee.wav', sr=44100)
spec = np.abs(librosa.stft(y, n_fft=512, hop_length=512))
n_fft=2048
hop_size=n_fft
model = pickle.load(open('./renyi_shannon_prollharm_800.sav', 'rb'))
kernel = [800,800]
pct=30
res = 3

# %%
ers_no_norm = ers(y, res, kernel, model, pct, normalize=False, n_fft=n_fft, hop_size=n_fft)
ers_norm_peak = ers(y, res, kernel, model, pct, normalize=True, n_fft=n_fft, hop_size=n_fft)
ers_norm_fft = ers(y, res, kernel, model, pct, normalize=False, norm_fft=True, n_fft=n_fft, hop_size=n_fft)

# %%
ers_no_norm_vis = ers_no_norm.generate_visualization()
ers_norm_peak_vis = ers_norm_peak.generate_visualization()
ers_norm_fft_vis = ers_norm_fft.generate_visualization()

# %%
plt.figure(figsize=[15,5])

plt.subplot(1,3,1)
librosa.display.specshow(librosa.amplitude_to_db(ers_no_norm_vis, ref=np.max), sr=44100,  hop_length=2048, y_axis='log', x_axis='time')
plt.title('ERS with no normalization', fontsize=15)

plt.subplot(1,3,2)
librosa.display.specshow(librosa.amplitude_to_db(ers_norm_peak_vis, ref=np.max), sr=44100,  hop_length=2048, y_axis='log', x_axis='time')
plt.title('ERS with peak matching normalization', fontsize=15)

plt.subplot(1,3,3)
librosa.display.specshow(librosa.amplitude_to_db(ers_norm_fft_vis, ref=np.max), sr=44100,  hop_length=2048, y_axis='log', x_axis='time')
plt.title("ERS with Parseval's id. normalization", fontsize=15)
# Out:
# Text(0.5, 1.0, "ERS with Parseval's id. normalization")

# %% [markdown]
# ### 3. Plot da inserção e over-representation

# %%
y, sr = librosa.load('../../midi-experiment/notebooks/testee.wav', sr=44100)
spec = np.abs(librosa.stft(y, n_fft=512, hop_length=512))
time_span = [0,len(y)/sr]
_, y_axis = stft_zoom.get_axes_values(sr, 0, time_span, spec.shape) 
shannon, renyi = mappings.extract_features(spec, [800,800], n_fft=512, hop_size=512, sr=sr, fft_freqs=y_axis)

# %%
n_fft=512
hop_size=512
model = pickle.load(open('./renyi_shannon_prollharm_800.sav', 'rb'))
kernel = [800,800]
pct=50
res = 5


spec = np.abs(librosa.stft(y, n_fft=n_fft, hop_length=hop_size))
time_span = [0,len(y)/sr]
x_axis, y_axis = stft_zoom.get_axes_values(sr, 0, time_span, spec.shape)
base_spec = SingleResSpectrogram(spec, x_axis, y_axis)
multires_spec = MultiResSpectrogram(base_spec)
indices, original_shape = detect_musical_regions.detect_musical_regions(model, spec, kernel=kernel, mode='pct', pct_or_threshold=pct, n_fft=n_fft, hop_size=hop_size)
to_be_refined = detect_musical_regions.musical_regions_to_ranges(indices, original_shape, x_axis, y_axis, kernel, n_fft=n_fft, hop_size=hop_size)

stft_zoom.set_signal_bank(y,kernel)

for subregion in to_be_refined[:1]:
    freq_range = subregion[0]
    time_range = subregion[1]
    print(freq_range, time_range)
    spec_zoom, x_axis, y_axis, new_sr, window_size, hop_size = stft_zoom.stft_zoom(y, freq_range, time_range, sr=sr, original_window_size=n_fft, k=res)
    refined_subspec = SingleResSpectrogram(spec_zoom, x_axis, y_axis)
    multires_spec.insert_zoom(multires_spec.base_spec, refined_subspec, zoom_level=1)
# Out:
# /Users/nicolas/Library/Python/3.7/lib/python/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator GaussianNB from version 0.22.2.post1 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# [344.53125, 602.9296875] [3.1997699242298543, 4.012773629777114]

# %%
_, y_axis_spec = stft_zoom.get_axes_values(sr, 0, time_span, spec.shape)

# %%
y_axis
# Out:
# array([336.31112132, 353.60523897, 370.89935662, 388.19347426,
#        405.48759191, 422.78170956, 440.07582721, 457.36994485,
#        474.6640625 , 491.95818015, 509.25229779, 526.54641544,
#        543.84053309, 561.13465074, 578.42876838, 595.72288603,
#        613.01700368])

# %%
spec_zoom.shape
# Out:
# (17, 72)

# %%
len(y_axis)
# Out:
# 17

# %%
17*72
# Out:
# 1224

# %%
y_axis
# Out:
# array([336.31112132, 353.60523897, 370.89935662, 388.19347426,
#        405.48759191, 422.78170956, 440.07582721, 457.36994485,
#        474.6640625 , 491.95818015, 509.25229779, 526.54641544,
#        543.84053309, 561.13465074, 578.42876838, 595.72288603,
#        613.01700368])

# %%
plt.figure(figsize=[4,4])
plt.imshow(librosa.amplitude_to_db(spec_zoom, ref=np.max), aspect='auto', cmap='inferno', origin='lower')
plt.gca().set_yticks(range(len(y_axis)))
plt.gca().set_yticklabels(y_axis)
# Out:
# [Text(0, 0, '336.3111213235294'),
#  Text(0, 0, '353.60523897058823'),
#  Text(0, 0, '370.8993566176471'),
#  Text(0, 0, '388.19347426470586'),
#  Text(0, 0, '405.4875919117647'),
#  Text(0, 0, '422.78170955882354'),
#  Text(0, 0, '440.0758272058823'),
#  Text(0, 0, '457.36994485294116'),
#  Text(0, 0, '474.6640625'),
#  Text(0, 0, '491.9581801470588'),
#  Text(0, 0, '509.2522977941176'),
#  Text(0, 0, '526.5464154411765'),
#  Text(0, 0, '543.8405330882352'),
#  Text(0, 0, '561.1346507352941'),
#  Text(0, 0, '578.4287683823529'),
#  Text(0, 0, '595.7228860294117'),
#  Text(0, 0, '613.0170036764705')]

# %%
plt.figure(figsize=[6,6])
display.specshow(librosa.amplitude_to_db(spec[4:7,275:344], ref=np.max(spec)), _[275:344], y_axis[4:7])

# %%
plt.figure(figsize=[6,6])
display.specshow(librosa.amplitude_to_db(spec_zoom, ref=np.max), x_axis, y_axis)

# %%
plt.figure(figsize=[8,8])
librosa.display.specshow(librosa.amplitude_to_db(multires_spec.generate_visualization(), ref=np.max), y_axis='log', sr=44100)

# %% [markdown]
# ### 4. Signal bank

# %%
y, sr = librosa.load('../../midi-experiment/notebooks/testee.wav', sr=44100)

# %%
librosa.display.waveplot(y, sr=sr)

# %%
stft_zoom.set_signal_bank(y, [800,800])

# %%
stft_zoom.y_bank[1][0]
# Out:
# array([ 1.68036048e-07,  5.02416028e-07,  8.33190345e-07, ...,
#        -8.63231087e-04, -8.82084188e-04, -9.00805298e-04])

# %%
librosa.display.waveplot(stft_zoom.y_bank[-1][0], sr=sr)

# %% [markdown]
# ### 5. Plots exemplo da ERS

# %%
y, sr = librosa.load('../../midi-experiment/notebooks/testee.wav', sr=44100)

# %%
def ers(y, res, kernel, model, pct, sr=44100, n_fft=512, hop_size=512, normalize=True):
    spec = np.abs(librosa.stft(y, n_fft=n_fft, hop_length=hop_size))
    time_span = [0,len(y)/sr]
    x_axis, y_axis = stft_zoom.get_axes_values(sr, 0, time_span, spec.shape) 
    base_spec = SingleResSpectrogram(spec, x_axis, y_axis)
    multires_spec = MultiResSpectrogram(base_spec)
    indices, original_shape = detect_musical_regions.detect_musical_regions(model, spec, kernel=kernel, mode='pct', pct_or_threshold=pct, n_fft=n_fft, hop_size=hop_size)
    to_be_refined = detect_musical_regions.musical_regions_to_ranges(indices, original_shape, x_axis, y_axis, kernel, n_fft=n_fft, hop_size=hop_size)

    stft_zoom.set_signal_bank(y,kernel, n_fft=n_fft)

    for subregion in to_be_refined:
        freq_range = subregion[0]
        time_range = subregion[1]
        spec_zoom, x_axis, y_axis, new_sr, window_size, hop_size = stft_zoom.stft_zoom(y, freq_range, time_range, sr=sr, original_window_size=n_fft, k=res)
        refined_subspec = SingleResSpectrogram(spec_zoom, x_axis, y_axis)
        multires_spec.insert_zoom(multires_spec.base_spec, refined_subspec, freq_range, zoom_level=1, normalize=normalize)
        
    return multires_spec

def ers_multilevel(y, res_list, kernel_list, model, pct_list, sr=44100, n_fft=512, hop_size=512, normalize=True):
    o_n_fft = n_fft
    o_hop_size = hop_size
    spec = np.abs(librosa.stft(y, n_fft=n_fft, hop_length=hop_size))
    time_span = [0,len(y)/sr]
    x_axis, y_axis = stft_zoom.get_axes_values(sr, 0, time_span, spec.shape) 
    base_spec = SingleResSpectrogram(spec, x_axis, y_axis)
    multires_spec = MultiResSpectrogram(base_spec)
    
    kernel = kernel_list[0]
    indices, original_shape = detect_musical_regions.detect_musical_regions(model, spec, kernel=kernel, mode='pct', pct_or_threshold=pct_list[0], n_fft=n_fft, hop_size=hop_size)
    to_be_refined = detect_musical_regions.musical_regions_to_ranges(indices, original_shape, x_axis, y_axis, kernel, n_fft=n_fft, hop_size=hop_size)

    stft_zoom.set_signal_bank(y,kernel, n_fft=n_fft)
    
    for subregion in to_be_refined:
        freq_range = subregion[0]
        time_range = subregion[1]
        spec_zoom, x_axis, y_axis, new_sr, window_size, hop_size = stft_zoom.stft_zoom(y, freq_range, time_range, sr=sr, original_window_size=n_fft, k=res_list[0])
        refined_subspec = SingleResSpectrogram(spec_zoom, x_axis, y_axis, n_fft=window_size, hop_size=hop_size, sr=new_sr)
        multires_spec.insert_zoom(multires_spec.base_spec, refined_subspec, freq_range, zoom_level=1, normalize=normalize)
        
    i = 1
    for kernel in kernel_list[1:]:
        i += 1
#         print(res_list[i-1])
        if i == 2:
            spec_list = multires_spec.first_zoom
        elif i == 3:
            spec_list = multires_spec.second_zoom
        elif i == 4:
            spec_list = multires_spec.third_zoom

        to_be_further_refined = []
        for spec_zoom in spec_list:
            spec        = np.array(spec_zoom.spec, dtype=float)
            x_axis      = spec_zoom.x_axis
            y_axis      = spec_zoom.y_axis
            sr          = spec_zoom.sr
            window_size = spec_zoom.n_fft
            hop_size    = spec_zoom.hop_size
            
            if len(y_axis) == 1 or len(x_axis) == 1:
                continue
            
            indices, original_shape = detect_musical_regions.detect_musical_regions(model, spec, mode='pct', pct_or_threshold=pct_list[i-1], kernel=kernel, n_fft=window_size, hop_size=hop_size, sr=sr, y_axis=y_axis)
            to_be_further_refined.append([spec_zoom, detect_musical_regions.musical_regions_to_ranges(indices, original_shape, x_axis, y_axis, kernel, sr=sr, hop_size=hop_size)])

        sr = 44100
        hop_size = o_hop_size
        n_fft = o_n_fft
        time_step = o_hop_size / sr
        for subregion in to_be_further_refined:
            base_spec = subregion[0]
            for ranges in subregion[1]:
                freq_range = ranges[0]
                time_range = ranges[1]
                # Compensacao da centralizacao das janelas no tempo e STFT centrada em 0
                time_range[0] -= time_step/2
                time_range[1] += time_step/2
                if time_range[0] < 0:
                    time_range[0] = 0

                spec_zoom, x_axis, y_axis, new_sr, window_size, hop_size = stft_zoom.stft_zoom(y, freq_range, time_range, sr=sr, original_window_size=n_fft, k=res_list[i-1])
                refined_subspec = SingleResSpectrogram(spec_zoom, x_axis, y_axis, n_fft=window_size, hop_size=hop_size, sr=new_sr)
                multires_spec.insert_zoom(base_spec, refined_subspec, freq_range, zoom_level=i, normalize=normalize)
    return multires_spec

# %%
n_fft=512
hop_size=512
model = pickle.load(open('./renyi_shannon_prollharm_800.sav', 'rb'))
kernel = [800,800]
pct=35
res = 8
# Out:
# /Users/nicolas/Library/Python/3.7/lib/python/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator GaussianNB from version 0.22.2.post1 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
ers_1600 = ers(y, res, [1600,1600], model, pct, sr=44100, n_fft=n_fft, hop_size=hop_size)
ers_800 = ers(y, res, [800,800], model, pct, sr=44100, n_fft=n_fft, hop_size=hop_size)
ers_400 = ers(y, res, [400,400], model, pct, sr=44100, n_fft=n_fft, hop_size=hop_size)
ers_200 = ers(y, res, [200,200], model, pct, sr=44100, n_fft=n_fft, hop_size=hop_size)

# %%
spec = librosa.amplitude_to_db(np.abs(librosa.stft(y, n_fft=512, hop_length=512)), ref=np.max)

# %%
plt.figure(figsize=[25,5])

plt.subplot(1,5,1)
librosa.display.specshow(spec, y_axis='log', sr=44100)
plt.title('Original spectrogram', fontsize=18)

plt.subplot(1,5,2)
librosa.display.specshow(librosa.amplitude_to_db(ers_1600.generate_visualization(), ref=np.max), y_axis='log', sr=44100)
plt.title('ERS - 1600x1600 subregion', fontsize=18)

plt.subplot(1,5,3)
librosa.display.specshow(librosa.amplitude_to_db(ers_800.generate_visualization(), ref=np.max), y_axis='log', sr=44100)
plt.title('ERS - 800x800 subregion', fontsize=18)

plt.subplot(1,5,4)
librosa.display.specshow(librosa.amplitude_to_db(ers_400.generate_visualization(), ref=np.max), y_axis='log', sr=44100)
plt.title('ERS - 400x400 subregion', fontsize=18)

plt.subplot(1,5,5)
librosa.display.specshow(librosa.amplitude_to_db(ers_200.generate_visualization(), ref=np.max), y_axis='log', sr=44100)
plt.title('ERS - 200x200 subregion', fontsize=18)

plt.tight_layout()

# %%
n_fft=512
res = [2,4,8,16]
kernels = [[1600,1600], [800,800], [400,400], [200,200]]
pct = [35,75,75,75]

ers_1600 = ers(y, 2, [1600,1600], model, 35, sr=44100, n_fft=n_fft, hop_size=hop_size)
ers_multi_4 = ers_multilevel(y, res, kernels, model, pct, sr=44100, n_fft=n_fft, hop_size=hop_size)
ers_multi_3 = ers_multilevel(y, res, [[1600,1600], [800,800], [400,400]], model, pct, sr=44100, n_fft=n_fft, hop_size=hop_size)
ers_multi_2 = ers_multilevel(y, res, [[1600,1600], [800,800]], model, pct, sr=44100, n_fft=n_fft, hop_size=hop_size)
spec = librosa.amplitude_to_db(np.abs(librosa.stft(y, n_fft=512, hop_length=512)), ref=np.max)

# %%
plt.figure(figsize=[25,5])

plt.subplot(1,5,1)
librosa.display.specshow(spec, y_axis='log', sr=44100)
plt.title('Original spectrogram', fontsize=18)

plt.subplot(1,5,2)
librosa.display.specshow(librosa.amplitude_to_db(ers_1600.generate_visualization(), ref=np.max), y_axis='log', sr=44100)
plt.title('ERS - 1 level', fontsize=18)

plt.subplot(1,5,3)
librosa.display.specshow(librosa.amplitude_to_db(ers_multi_2.generate_visualization(), ref=np.max), y_axis='log', sr=44100)
plt.title('ERS - 2 levels', fontsize=18)

plt.subplot(1,5,4)
librosa.display.specshow(librosa.amplitude_to_db(ers_multi_3.generate_visualization(), ref=np.max), y_axis='log', sr=44100)
plt.title('ERS - 3 levels', fontsize=18)

plt.subplot(1,5,5)
librosa.display.specshow(librosa.amplitude_to_db(ers_multi_4.generate_visualization(), ref=np.max), y_axis='log', sr=44100)
plt.title('ERS - 4 levels', fontsize=18)

plt.tight_layout()

# %%
ers_800_10 = ers(y, res, [800,800], model, 10, sr=44100, n_fft=n_fft, hop_size=hop_size)
ers_800_25 = ers(y, res, [800,800], model, 25, sr=44100, n_fft=n_fft, hop_size=hop_size)
ers_800_50 = ers(y, res, [800,800], model, 50, sr=44100, n_fft=n_fft, hop_size=hop_size)
ers_800_75 = ers(y, res, [800,800], model, 75, sr=44100, n_fft=n_fft, hop_size=hop_size)

# %%
plt.figure(figsize=[25,5])

plt.subplot(1,5,1)
librosa.display.specshow(spec, y_axis='log', sr=44100)
plt.title('Original spectrogram', fontsize=18)

plt.subplot(1,5,2)
librosa.display.specshow(librosa.amplitude_to_db(ers_800_10.generate_visualization(), ref=np.max), y_axis='log', sr=44100)
plt.title('ERS - 10% refined', fontsize=18)

plt.subplot(1,5,3)
librosa.display.specshow(librosa.amplitude_to_db(ers_800_25.generate_visualization(), ref=np.max), y_axis='log', sr=44100)
plt.title('ERS - 25% refined', fontsize=18)

plt.subplot(1,5,4)
librosa.display.specshow(librosa.amplitude_to_db(ers_800_50.generate_visualization(), ref=np.max), y_axis='log', sr=44100)
plt.title('ERS - 50% refined', fontsize=18)

plt.subplot(1,5,5)
librosa.display.specshow(librosa.amplitude_to_db(ers_800_75.generate_visualization(), ref=np.max), y_axis='log', sr=44100)
plt.title('ERS - 75% refined', fontsize=18)

plt.tight_layout()

# %%
ers_800_2 = ers(y, 2, [800,800], model, 50, sr=44100, n_fft=n_fft, hop_size=hop_size)
ers_800_8 = ers(y, 8, [800,800], model, 50, sr=44100, n_fft=n_fft, hop_size=hop_size)
ers_800_32 = ers(y, 32, [800,800], model, 50, sr=44100, n_fft=n_fft, hop_size=hop_size)
ers_800_64 = ers(y, 64, [800,800], model, 50, sr=44100, n_fft=n_fft, hop_size=hop_size)

# %%
plt.figure(figsize=[25,5])

plt.subplot(1,5,1)
librosa.display.specshow(spec, y_axis='log', sr=44100)
plt.title('Original spectrogram', fontsize=18)

plt.subplot(1,5,2)
librosa.display.specshow(librosa.amplitude_to_db(ers_800_2.generate_visualization(), ref=np.max), y_axis='log', sr=44100)
plt.title('ERS - k=2', fontsize=18)

plt.subplot(1,5,3)
librosa.display.specshow(librosa.amplitude_to_db(ers_800_8.generate_visualization(), ref=np.max), y_axis='log', sr=44100)
plt.title('ERS - k=8', fontsize=18)

plt.subplot(1,5,4)
librosa.display.specshow(librosa.amplitude_to_db(ers_800_32.generate_visualization(), ref=np.max), y_axis='log', sr=44100)
plt.title('ERS - k=32', fontsize=18)

plt.subplot(1,5,5)
librosa.display.specshow(librosa.amplitude_to_db(ers_800_64.generate_visualization(), ref=np.max), y_axis='log', sr=44100)
plt.title('ERS - k=64', fontsize=18)

plt.tight_layout()
